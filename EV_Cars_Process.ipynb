# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv("ev_cars_raw.csv")

# %%
a = raw.head(900)

# %%
a
# Out:
#                                      Car
# 0                                 Tesla
# 1          Model 3 Long Range Dual Motor
# 2    Battery Electric Vehicle | 70 kWh *
# 3                                      D
# 4                                      5
# ..                                   ...
# 895                           Fastcharge
# 896                              210 mph
# 897                             € 34,110
# 898                             € 34,399
# 899                              £30,540
#
# [900 rows x 1 columns]

# %%
pd.DataFrame(np.reshape(a.values,(50,18)))
# Out:
#              0                                1  \
# 0       Tesla     Model 3 Long Range Dual Motor
# 1        Dacia                  Spring Electric
# 2         Kia                            EV6 GT
# 3       Skoda                       Enyaq iV 80
# 4       Tesla     Model Y Long Range Dual Motor
# 5       Nissan                             Leaf
# 6        Tesla  Model 3 Standard Range Plus LFP
# 7        Tesla      Model 3 Standard Range Plus
# 8      Hyundai             Kona Electric 64 kWh
# 9          MG              Marvel R Performance
# 10    Hyundai            IONIQ 5 Long Range AWD
# 11   Mercedes                    EQS 580 4MATIC
# 12          MG                            ZS EV
# 13     Peugeot                            e-208
# 14     Hyundai                   IONIQ Electric
# 15    Mercedes                          EQA 250
# 16    Mercedes                          EQE 350
# 17         BMW                      iX xDrive50
# ...

# %%
# Out:
# array([['Tesla Model 3 Long Range Dual MotorTesla Model 3 Long Range Dual Motor',
#         'Battery Electric Vehicle | 70 kWh *', ' D5', '0 - 62',
#         '4.4 sec', 'Top Speed', '145 mph', 'Range', '280 mi',
#         'Efficiency', '250 Wh/mi', 'Fastcharge', '400 mph', nan, nan,
#         '£48,490'],
#        ['Dacia Spring ElectricDacia Spring Electric',
#         'Battery Electric Vehicle | 26.8 kWh *', ' A4', '0 - 62*',
#         '15.0 sec', 'Top Speed', '78 mph', 'Range*', '105 mi',
#         'Efficiency*', '255 Wh/mi', 'Fastcharge', '75 mph', '€ 20,490',
#         '€ 17,890', nan]], dtype=object)

# %%
df = pd.DataFrame(np.reshape(raw.values,(185,18)))

# %%
df.head(10)
# Out:
#          0                                1  \
# 0   Tesla     Model 3 Long Range Dual Motor
# 1    Dacia                  Spring Electric
# 2     Kia                            EV6 GT
# 3   Skoda                       Enyaq iV 80
# 4   Tesla     Model Y Long Range Dual Motor
# 5   Nissan                             Leaf
# 6    Tesla  Model 3 Standard Range Plus LFP
# 7    Tesla      Model 3 Standard Range Plus
# 8  Hyundai             Kona Electric 64 kWh
# 9      MG              Marvel R Performance
#
#                                        2  3    4        5         6  \
# 0    Battery Electric Vehicle | 70 kWh *  D    5   0 - 62   4.4 sec
# 1  Battery Electric Vehicle | 26.8 kWh *  A    4  0 - 62*  15.0 sec
# 2  Battery Electric Vehicle | 77.4 kWh *  C    5   0 - 62   3.5 sec
# 3      Battery Electric Vehicle | 77 kWh  C    5   0 - 62   8.6 sec
# 4    Battery Electric Vehicle | 70 kWh *  D    7   0 - 62   5.0 sec
# ...

# %%
df.to_excel("ev_cars_step_1.xls")
