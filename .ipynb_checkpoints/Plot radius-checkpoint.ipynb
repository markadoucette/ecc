# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import requests, io, json
import random
import plotly.express as px

import geopandas as gpd
import shapely.geometry

# %%
from ev import *
from radius_map import *

# %%
# bring in EV Data

ev_raw = pd.read_csv('./app/data_files/ev_car_final.csv',index_col=0)

ev_raw,ev_range,ev_df = ev_data(ev_raw)

# US Zip Code and Lat / Long Dataset    
us_zip_lat_long_data = pd.read_csv('./app/data_files/us_zip_code_lat_long.csv'
                                   ,dtype={'ZIP': str,'LAT': float,'LNG': float})

# %%
# # # Get distinct Brands
# brands = ev_df['Brand'].unique()
# brands
# Out:
# array(['Aiways', 'Audi', 'BMW', 'Byton', 'Citroen', 'CUPRA', 'Dacia',
#        'DS 3', 'Fiat', 'Ford', 'Honda', 'Hyundai', 'Hyundai ', 'Jaguar',
#        'Kia', 'Kia ', 'Lexus', 'Lightyear', 'Lucid Air', 'Mazda',
#        'Mercedes', 'Mercedes ', 'MG', 'MG ', 'Mini', 'Nissan', 'Opel',
#        'Peugeot', 'Polestar', 'Porsche', 'Renault', 'SEAT', 'Skoda',
#        'Skoda ', 'Smart', 'Sono', 'Tesla', 'Tesla ', 'Toyota',
#        'Volkswagen', 'Volvo'], dtype=object)

# %%
# # ev_df.loc[(ev_df['Brand']== 'Ford')]
# brand_1 = 'Tesla'
# # brand_2 = 'Volkswagen'

# %%
# # # Get Distinct models from brands
# models = ev_df.index[(ev_df['Brand']== brand_1)].unique()
# models

# %%
## Car 1
# brand_1 = 'Ford'
car_1 = 'Mustang Mach-E SR AWD'

## Car 2
# brand_2 = 'Volkswagen'
car_2 = 'ID.4 GTX'

# %%
## Set Distiance
range_1 = get_range(ev_range,car_1)
range_2 = get_range(ev_range,car_2)

# %%
## Set Zip 
# zip_search = input("Zip: ")
zip = '32026'

# %%
# # Plot Map
# radius_map(zip,us_zip_lat_long_data,range_1,range_2)

# %%
ev_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176 entries, U5 to XC40 Recharge Twin Pure Electric
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Brand                          176 non-null    object
#  1   Battery Size (kWh)             176 non-null    float64
#  2   Segment                        176 non-null    object
#  3   Powertrian                     176 non-null    object
#  4   BodyStyle                      176 non-null    object
#  5   Seats                          176 non-null    int64
#  6   0 - 62 MPH (Sec)               176 non-null    object
#  7   Top Speed (MPH)                176 non-null    object
#  8   Range (Mi)                     176 non-null    object
#  9   Efficiency (Wh/mi)             176 non-null    object
#  10  Euro                           176 non-null    float64
#  11  0 - 62 MPH (Sec) Estimation    176 non-null    int64
#  12  Top Speed (MPH) Estimation     176 non-null    int64
#  13  Range (Mi) Estimation          176 non-null    int64
#  14  Efficiency (Wh/mi) Estimation  176 non-null    int64
#  15  0_62_mph_raw                   176 non-null    float64
#  16  top_speed_raw                  176 non-null    float64
#  17  range_raw                      176 non-null    float64
#  18  efficiency_raw                 176 non-null    float64
# dtypes: float64(6), int64(5), object(8)
# memory usage: 32.5+ KB

# %%
ev_df = ev_raw.iloc[:,[1,3,4,5,15,16,17,18]]
ev_df = pd.get_dummies(ev_df,drop_first = True).T

# %%
ev_df
# Out:
# Model                   U5  e-tron 50 quattro  e-tron 55 quattro  \
# Battery Size (kWh)    63.0               64.7               86.5
# Seats                  5.0                5.0                5.0
# 0_62_mph_raw           7.5                6.8                5.7
# top_speed_raw         93.0              118.0              124.0
# range_raw            210.0              260.0              250.0
# efficiency_raw       300.0              365.0              380.0
# Powertrian_FWD         1.0                0.0                0.0
# Powertrian_RWD         0.0                0.0                0.0
# BodyStyle_Hatchback    0.0                0.0                0.0
# BodyStyle_Liftback     0.0                0.0                0.0
# BodyStyle_MPV          0.0                0.0                0.0
# BodyStyle_Mini Van     0.0                0.0                0.0
# BodyStyle_Pickup       0.0                0.0                0.0
# BodyStyle_SUV          1.0                1.0                1.0
# BodyStyle_Sedan        0.0                0.0                0.0
#
# Model                e-tron GT quattro  e-tron GT RS  e-tron S 55 quattro  \
# Battery Size (kWh)                85.0          85.0                 86.5
# Seats                              4.0           4.0                  5.0
# 0_62_mph_raw                       4.1           3.3                  4.5
# top_speed_raw                    152.0         155.0                130.0
# range_raw                        205.0         175.0                250.0
# efficiency_raw                   325.0         340.0                430.0
# Powertrian_FWD                     0.0           0.0                  0.0
# Powertrian_RWD                     0.0           0.0                  0.0
# BodyStyle_Hatchback                0.0           0.0                  0.0
# BodyStyle_Liftback                 0.0           0.0                  0.0
# BodyStyle_MPV                      0.0           0.0                  0.0
# BodyStyle_Mini Van                 0.0           0.0                  0.0
# BodyStyle_Pickup                   0.0           0.0                  0.0
# BodyStyle_SUV                      0.0           0.0                  1.0
# BodyStyle_Sedan                    1.0           1.0                  0.0
#
# Model                e-tron S Sportback 55 quattro  \
# Battery Size (kWh)                            86.5
# Seats                                          5.0
# 0_62_mph_raw                                   4.5
# top_speed_raw                                130.0
# range_raw                                    240.0
# efficiency_raw                               420.0
# Powertrian_FWD                                 0.0
# Powertrian_RWD                                 0.0
# BodyStyle_Hatchback                            0.0
# BodyStyle_Liftback                             0.0
# BodyStyle_MPV                                  0.0
# BodyStyle_Mini Van                             0.0
# BodyStyle_Pickup                               0.0
# BodyStyle_SUV                                  1.0
# BodyStyle_Sedan                                0.0
#
# Model                e-tron Sportback 50 quattro  e-tron Sportback 55 quattro  \
# Battery Size (kWh)                          64.7                         86.5
# Seats                                        5.0                          5.0
# 0_62_mph_raw                                 6.8                          5.7
# top_speed_raw                              118.0                        124.0
# range_raw                                  240.0                        180.0
# efficiency_raw                             355.0                        375.0
# Powertrian_FWD                               0.0                          0.0
# Powertrian_RWD                               0.0                          0.0
# BodyStyle_Hatchback                          0.0                          0.0
# BodyStyle_Liftback                           0.0                          0.0
# BodyStyle_MPV                                0.0                          0.0
# BodyStyle_Mini Van                           0.0                          0.0
# BodyStyle_Pickup                             0.0                          0.0
# BodyStyle_SUV                                1.0                          1.0
# BodyStyle_Sedan                              0.0                          0.0
#
# Model                e-tron Sportback 55 quattro  ...  ID.3 Pro S - 4 Seats  \
# Battery Size (kWh)                          86.5  ...                  77.0
# Seats                                        5.0  ...                   4.0
# 0_62_mph_raw                                 5.7  ...                   7.9
# top_speed_raw                              124.0  ...                  99.0
# range_raw                                  265.0  ...                 280.0
# efficiency_raw                             375.0  ...                 275.0
# Powertrian_FWD                               0.0  ...                   0.0
# Powertrian_RWD                               0.0  ...                   1.0
# BodyStyle_Hatchback                          0.0  ...                   1.0
# BodyStyle_Liftback                           0.0  ...                   0.0
# BodyStyle_MPV                                0.0  ...                   0.0
# BodyStyle_Mini Van                           0.0  ...                   0.0
# BodyStyle_Pickup                             0.0  ...                   0.0
# BodyStyle_SUV                                1.0  ...                   0.0
# BodyStyle_Sedan                              0.0  ...                   0.0
#
# Model                ID.3 Pro S - 5 Seats  ID.3 Pure Performance  ID.4 GTX  \
# Battery Size (kWh)                   77.0                   45.0      77.0
# Seats                                 5.0                    5.0       5.0
# 0_62_mph_raw                          7.9                    8.9       6.2
# top_speed_raw                        99.0                   99.0     112.0
# range_raw                           280.0                  170.0     245.0
# efficiency_raw                      275.0                  260.0     310.0
# Powertrian_FWD                        0.0                    0.0       0.0
# Powertrian_RWD                        1.0                    1.0       0.0
# BodyStyle_Hatchback                   1.0                    1.0       0.0
# BodyStyle_Liftback                    0.0                    0.0       0.0
# BodyStyle_MPV                         0.0                    0.0       0.0
# BodyStyle_Mini Van                    0.0                    0.0       0.0
# BodyStyle_Pickup                      0.0                    0.0       0.0
# BodyStyle_SUV                         0.0                    0.0       1.0
# BodyStyle_Sedan                       0.0                    0.0       0.0
#
# Model                ID.4 Pro Performance  ID.4 Pure  ID.4 Pure Performance  \
# Battery Size (kWh)                   77.0       52.0                   52.0
# Seats                                 5.0        5.0                    5.0
# 0_62_mph_raw                          8.5       10.9                    9.0
# top_speed_raw                        99.0       99.0                   99.0
# range_raw                           255.0      175.0                  175.0
# efficiency_raw                      300.0      295.0                  295.0
# Powertrian_FWD                        0.0        0.0                    0.0
# Powertrian_RWD                        1.0        1.0                    1.0
# BodyStyle_Hatchback                   0.0        0.0                    0.0
# BodyStyle_Liftback                    0.0        0.0                    0.0
# BodyStyle_MPV                         0.0        0.0                    0.0
# BodyStyle_Mini Van                    0.0        0.0                    0.0
# BodyStyle_Pickup                      0.0        0.0                    0.0
# BodyStyle_SUV                         1.0        1.0                    1.0
# BodyStyle_Sedan                       0.0        0.0                    0.0
#
# Model                C40 Recharge  XC40 Recharge Pure Electric  \
# Battery Size (kWh)           75.0                         67.0
# Seats                         5.0                          5.0
# 0_62_mph_raw                  4.7                          7.4
# top_speed_raw               112.0                         99.0
# range_raw                   210.0                        195.0
# efficiency_raw              355.0                        340.0
# Powertrian_FWD                0.0                          1.0
# Powertrian_RWD                0.0                          0.0
# BodyStyle_Hatchback           0.0                          0.0
# BodyStyle_Liftback            0.0                          0.0
# BodyStyle_MPV                 0.0                          0.0
# BodyStyle_Mini Van            0.0                          0.0
# BodyStyle_Pickup              0.0                          0.0
# BodyStyle_SUV                 1.0                          1.0
# BodyStyle_Sedan               0.0                          0.0
#
# Model                XC40 Recharge Twin Pure Electric
# Battery Size (kWh)                               76.0
# Seats                                             5.0
# 0_62_mph_raw                                      4.9
# top_speed_raw                                   112.0
# range_raw                                       210.0
# efficiency_raw                                  355.0
# Powertrian_FWD                                    0.0
# Powertrian_RWD                                    0.0
# BodyStyle_Hatchback                               0.0
# BodyStyle_Liftback                                0.0
# BodyStyle_MPV                                     0.0
# BodyStyle_Mini Van                                0.0
# BodyStyle_Pickup                                  0.0
# BodyStyle_SUV                                     1.0
# BodyStyle_Sedan                                   0.0
#
# [15 rows x 176 columns]

# %%
ev_df.corr()
# Out:
# Model                                   U5  e-tron 50 quattro  \
# Model
# U5                                1.000000           0.999474
# e-tron 50 quattro                 0.999474           1.000000
# e-tron 55 quattro                 0.999123           0.998042
# e-tron GT quattro                 0.987849           0.987231
# e-tron GT RS                      0.977518           0.976152
# ...                                    ...                ...
# ID.4 Pure                         0.995754           0.995484
# ID.4 Pure Performance             0.995814           0.995566
# C40 Recharge                      0.996394           0.995073
# XC40 Recharge Pure Electric       0.995384           0.993974
# XC40 Recharge Twin Pure Electric  0.996368           0.994973
#
# Model                             e-tron 55 quattro  e-tron GT quattro  \
# Model
# U5                                         0.999123           0.987849
# e-tron 50 quattro                          0.998042           0.987231
# e-tron 55 quattro                          1.000000           0.992183
# e-tron GT quattro                          0.992183           1.000000
# e-tron GT RS                               0.984856           0.995940
# ...                                             ...                ...
# ID.4 Pure                                  0.997553           0.991731
# ID.4 Pure Performance                      0.997665           0.991895
# C40 Recharge                               0.998685           0.991720
# XC40 Recharge Pure Electric                0.997484           0.988230
# XC40 Recharge Twin Pure Electric           0.998700           0.991783
#
# Model                             e-tron GT RS  e-tron S 55 quattro  \
# Model
# U5                                    0.977518             0.995893
# e-tron 50 quattro                     0.976152             0.994610
# e-tron 55 quattro                     0.984856             0.998123
# e-tron GT quattro                     0.995940             0.989991
# e-tron GT RS                          1.000000             0.987754
# ...                                        ...                  ...
# ID.4 Pure                             0.988924             0.998995
# ID.4 Pure Performance                 0.989086             0.999106
# C40 Recharge                          0.988897             0.999893
# XC40 Recharge Pure Electric           0.986474             0.999873
# XC40 Recharge Twin Pure Electric      0.988966             0.999872
#
# Model                             e-tron S Sportback 55 quattro  \
# Model
# U5                                                     0.995026
# e-tron 50 quattro                                      0.993617
# e-tron 55 quattro                                      0.997733
# e-tron GT quattro                                      0.990790
# e-tron GT RS                                           0.989354
# ...                                                         ...
# ID.4 Pure                                              0.998934
# ID.4 Pure Performance                                  0.999047
# C40 Recharge                                           0.999867
# XC40 Recharge Pure Electric                            0.999770
# XC40 Recharge Twin Pure Electric                       0.999858
#
# Model                             e-tron Sportback 50 quattro  \
# Model
# U5                                                   0.999327
# e-tron 50 quattro                                    0.999558
# e-tron 55 quattro                                    0.999056
# e-tron GT quattro                                    0.990394
# e-tron GT RS                                         0.981803
# ...                                                       ...
# ID.4 Pure                                            0.997765
# ID.4 Pure Performance                                0.997845
# C40 Recharge                                         0.997370
# XC40 Recharge Pure Electric                          0.996361
# XC40 Recharge Twin Pure Electric                     0.997286
#
# Model                             e-tron Sportback 55 quattro  \
# Model
# U5                                                   0.983268
# e-tron 50 quattro                                    0.980653
# e-tron 55 quattro                                    0.989388
# e-tron GT quattro                                    0.988479
# e-tron GT RS                                         0.994156
# ...                                                       ...
# ID.4 Pure                                            0.993709
# ID.4 Pure Performance                                0.993804
# C40 Recharge                                         0.995078
# XC40 Recharge Pure Electric                          0.995210
# XC40 Recharge Twin Pure Electric                     0.995142
#
# Model                             e-tron Sportback 55 quattro  ...  \
# Model                                                          ...
# U5                                                   0.999668  ...
# e-tron 50 quattro                                    0.998940  ...
# e-tron 55 quattro                                    0.999364  ...
# e-tron GT quattro                                    0.990446  ...
# e-tron GT RS                                         0.979927  ...
# ...                                                       ...  ...
# ID.4 Pure                                            0.995178  ...
# ID.4 Pure Performance                                0.995294  ...
# C40 Recharge                                         0.996267  ...
# XC40 Recharge Pure Electric                          0.994618  ...
# XC40 Recharge Twin Pure Electric                     0.996277  ...
#
# Model                             ID.3 Pro S - 4 Seats  ID.3 Pro S - 5 Seats  \
# Model
# U5                                            0.980217              0.980226
# e-tron 50 quattro                             0.980775              0.980782
# e-tron 55 quattro                             0.973887              0.973884
# e-tron GT quattro                             0.959712              0.959686
# e-tron GT RS                                  0.932254              0.932225
# ...                                                ...                   ...
# ID.4 Pure                                     0.959713              0.959719
# ID.4 Pure Performance                         0.959815              0.959822
# C40 Recharge                                  0.961084              0.961086
# XC40 Recharge Pure Electric                   0.956901              0.956907
# XC40 Recharge Twin Pure Electric              0.961120              0.961121
#
# Model                             ID.3 Pure Performance  ID.4 GTX  \
# Model
# U5                                             0.996665  0.997377
# e-tron 50 quattro                              0.997426  0.997147
# e-tron 55 quattro                              0.997477  0.995665
# e-tron GT quattro                              0.994099  0.987365
# e-tron GT RS                                   0.987473  0.971973
# ...                                                 ...       ...
# ID.4 Pure                                      0.998418  0.988712
# ID.4 Pure Performance                          0.998435  0.988827
# C40 Recharge                                   0.996723  0.989654
# XC40 Recharge Pure Electric                    0.995331  0.986881
# XC40 Recharge Twin Pure Electric               0.996617  0.989676
#
# Model                             ID.4 Pro Performance  ID.4 Pure  \
# Model
# U5                                            0.994634   0.995754
# e-tron 50 quattro                             0.994313   0.995484
# e-tron 55 quattro                             0.991096   0.997553
# e-tron GT quattro                             0.978156   0.991731
# e-tron GT RS                                  0.958993   0.988924
# ...                                                ...        ...
# ID.4 Pure                                     0.981702   1.000000
# ID.4 Pure Performance                         0.981781   0.999984
# C40 Recharge                                  0.983110   0.999075
# XC40 Recharge Pure Electric                   0.980422   0.998871
# XC40 Recharge Twin Pure Electric              0.983143   0.998997
#
# Model                             ID.4 Pure Performance  C40 Recharge  \
# Model
# U5                                             0.995814      0.996394
# e-tron 50 quattro                              0.995566      0.995073
# e-tron 55 quattro                              0.997665      0.998685
# e-tron GT quattro                              0.991895      0.991720
# e-tron GT RS                                   0.989086      0.988897
# ...                                                 ...           ...
# ID.4 Pure                                      0.999984      0.999075
# ID.4 Pure Performance                          1.000000      0.999182
# C40 Recharge                                   0.999182      1.000000
# XC40 Recharge Pure Electric                    0.998923      0.999619
# XC40 Recharge Twin Pure Electric               0.999102      0.999997
#
# Model                             XC40 Recharge Pure Electric  \
# Model
# U5                                                   0.995384
# e-tron 50 quattro                                    0.993974
# e-tron 55 quattro                                    0.997484
# e-tron GT quattro                                    0.988230
# e-tron GT RS                                         0.986474
# ...                                                       ...
# ID.4 Pure                                            0.998871
# ID.4 Pure Performance                                0.998923
# C40 Recharge                                         0.999619
# XC40 Recharge Pure Electric                          1.000000
# XC40 Recharge Twin Pure Electric                     0.999596
#
# Model                             XC40 Recharge Twin Pure Electric
# Model
# U5                                                        0.996368
# e-tron 50 quattro                                         0.994973
# e-tron 55 quattro                                         0.998700
# e-tron GT quattro                                         0.991783
# e-tron GT RS                                              0.988966
# ...                                                            ...
# ID.4 Pure                                                 0.998997
# ID.4 Pure Performance                                     0.999102
# C40 Recharge                                              0.999997
# XC40 Recharge Pure Electric                               0.999596
# XC40 Recharge Twin Pure Electric                          1.000000
#
# [176 rows x 176 columns]

# %%
corr = ev_df.corr()

# %%
order_top10 = np.argsort(-corr.values, axis=1)[:, :10]

# %%
type(order_top10)
# Out:
# numpy.ndarray

# %%
order_top10[1]
# Out:
# array([  1, 134,   7, 133,   0, 137,  38,   9,  52, 117])

# %%
order_top10[2]
# Out:
# array([  2,  13,   9,   0,   7,  15,  45, 175,  63, 173])

# %%
g = order_top10[2]

# %%
corr.columns[order_top10][2][2]
# Out:
# <ipython-input-202-f7478a3cd615>:1: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# array(['e-tron 55 quattro', 'Q4 e-tron 50 quattro',
#        'e-tron Sportback 55 quattro', 'U5', 'e-tron Sportback 50 quattro',
#        'Q4 Sportback e-tron 40', 'Mustang Mach-E SR AWD',
#        'XC40 Recharge Twin Pure Electric', 'e-Soul 64 kWh',
#        'C40 Recharge'], dtype=object)

# %%
corr.to_numpy()[2][2]
# Out:
# 1.0

# %%
for i in order_top10[1]:
    print(corr.columns[i])
    print(u[1][i])
# Out:
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715

# %%
for j in order_top10[1]:
    print(corr.columns[1])
    
    for i in order_top10[1]:
        print(corr.columns[i])
        print(u[1][i])
# Out:
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715
# e-tron 50 quattro
# e-tron 50 quattro
# 1.0
# Zoe ZE50 R135
# 0.9997966623111505
# e-tron Sportback 50 quattro
# 0.999557999258747
# Zoe ZE50 R110
# 0.9995358143095987
# U5
# 0.9994741001874965
# Enyaq iV 60
# 0.9994201360166558
# Crossback E-Tense
# 0.9993702563865638
# e-tron Sportback 55 quattro
# 0.9989400162505903
# IONIQ 5 Standard Range AWD
# 0.9989267477628475
# 2 Standard Range Single Motor
# 0.9987528044738715

# %%
u = corr.to_numpy()

# %%
d_test = order_top10[:5]

# %%
order_top10[0][1]
# Out:
# 134

# %%
for i in order_top10[0]:
    print(corr.columns[i])
    print(u[0][i])
# Out:
# U5
# 1.0
# Zoe ZE50 R135
# 0.999772120304802
# e-tron Sportback 55 quattro
# 0.9996681020473611
# e-tron 50 quattro
# 0.9994741001874965
# Zoe ZE50 R110
# 0.9994411784688987
# e-tron Sportback 50 quattro
# 0.9993266712956692
# Enyaq iV 60
# 0.9991979294037016
# e-tron 55 quattro
# 0.99912338217556
# e-Soul 64 kWh
# 0.9987092063479217
# Q4 e-tron 50 quattro
# 0.9987069872086397

# %%
d_test[0][1]
# Out:
# 134

# %%
len(d_test[1])
# Out:
# 10

# %%
print(u[0][d_test[0][3]])
# Out:
# 0.9994741001874965

# %%
for i in d_test:
        for j in enumerate(d_test[i]):
            print(corr.columns[i])
#             print(u[i][d_test[i][j]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-266-8ef3fcace4d4> in <module>
#       1 for i in d_test:
# ----> 2         for j in enumerate(d_test[i]):
#       3             print(corr.columns[i])
#       4             print(u[i][d_test[i][j]])
#
# IndexError: index 134 is out of bounds for axis 0 with size 5

# %%
for i in d_test.items():
    print(corr.columns[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-238-8570217adca2> in <module>
# ----> 1 for i in d_test.items():
#       2     print(corr.columns[i])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %%
len(d_test)
# Out:
# 5

# %%
corr.columns[1]
# Out:
# 'e-tron 50 quattro'

# %%
h = similar[similar < 1].unstack().transpose().drop_duplicates()

# %%
similar = ev_df.corr()
np.fill_diagonal(similar.values, np.nan)

# %%
order_top10 = np.argsort(-similar.values, axis=1)[:, :10]

# %%
order_top10
# Out:
# array([[134,   9,   1, ...,  63,  13,  38],
#        [134,   7, 133, ...,  52, 117,  60],
#        [ 13,   9,   0, ...,  63, 173, 134],
#        ...,
#        [175,   5,   6, ...,  25, 171,  26],
#        [  5,   6, 173, ..., 172, 171,  26],
#        [173,   5,   6, ...,  26, 172, 171]])

# %%
result_top10 = pd.DataFrame(
    similar.columns[order_top10], 
    columns=['1st', '2nd','3rd','4th','5th','6th','7th','8th','9th','10th'],
    index=similar.index
)
# Out:
# <ipython-input-182-f0134010751f>:2: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.

# %%
result_top10
# Out:
#                                                                1st  \
# Model
# U5                                                   Zoe ZE50 R135
# e-tron 50 quattro                                    Zoe ZE50 R135
# e-tron 55 quattro                             Q4 e-tron 50 quattro
# e-tron GT quattro                     Taycan Turbo S Cross Turismo
# e-tron GT RS                                                i4 M50
# ...                                                            ...
# ID.4 Pure                                    ID.4 Pure Performance
# ID.4 Pure Performance                                    ID.4 Pure
# C40 Recharge                      XC40 Recharge Twin Pure Electric
# XC40 Recharge Pure Electric                    e-tron S 55 quattro
# XC40 Recharge Twin Pure Electric                      C40 Recharge
#
#                                                             2nd  \
# Model
# U5                                  e-tron Sportback 55 quattro
# e-tron 50 quattro                   e-tron Sportback 50 quattro
# e-tron 55 quattro                   e-tron Sportback 55 quattro
# e-tron GT quattro                    Taycan Turbo Cross Turismo
# e-tron GT RS                                           Marvel R
# ...                                                         ...
# ID.4 Pure                                         Zoe ZE40 R110
# ID.4 Pure Performance                             Zoe ZE40 R110
# C40 Recharge                                e-tron S 55 quattro
# XC40 Recharge Pure Electric       e-tron S Sportback 55 quattro
# XC40 Recharge Twin Pure Electric            e-tron S 55 quattro
#
#                                                             3rd  \
# Model
# U5                                            e-tron 50 quattro
# e-tron 50 quattro                                 Zoe ZE50 R110
# e-tron 55 quattro                                            U5
# e-tron GT quattro                                  Taycan Turbo
# e-tron GT RS                                             EV6 GT
# ...                                                         ...
# ID.4 Pure                                           Enyaq iV 50
# ID.4 Pure Performance                     Mustang Mach-E SR AWD
# C40 Recharge                      e-tron S Sportback 55 quattro
# XC40 Recharge Pure Electric                        C40 Recharge
# XC40 Recharge Twin Pure Electric  e-tron S Sportback 55 quattro
#
#                                                                4th  \
# Model
# U5                                                   Zoe ZE50 R110
# e-tron 50 quattro                                               U5
# e-tron 55 quattro                      e-tron Sportback 50 quattro
# e-tron GT quattro                                   Taycan Turbo S
# e-tron GT RS                                     e-tron GT quattro
# ...                                                            ...
# ID.4 Pure                                    Mustang Mach-E SR AWD
# ID.4 Pure Performance                                  Enyaq iV 50
# C40 Recharge                                 Mustang Mach-E SR AWD
# XC40 Recharge Pure Electric       XC40 Recharge Twin Pure Electric
# XC40 Recharge Twin Pure Electric             Mustang Mach-E SR AWD
#
#                                                           5th  \
# Model
# U5                                e-tron Sportback 50 quattro
# e-tron 50 quattro                                 Enyaq iV 60
# e-tron 55 quattro                      Q4 Sportback e-tron 40
# e-tron GT quattro                                        Pure
# e-tron GT RS                           EV6 Standard Range 2WD
# ...                                                       ...
# ID.4 Pure                                        C40 Recharge
# ID.4 Pure Performance                            C40 Recharge
# C40 Recharge                      XC40 Recharge Pure Electric
# XC40 Recharge Pure Electric                              Sion
# XC40 Recharge Twin Pure Electric  XC40 Recharge Pure Electric
#
#                                                       6th  \
# Model
# U5                                            Enyaq iV 60
# e-tron 50 quattro                       Crossback E-Tense
# e-tron 55 quattro                   Mustang Mach-E SR AWD
# e-tron GT quattro                                  i4 M50
# e-tron GT RS                                         Pure
# ...                                                   ...
# ID.4 Pure                                            Sion
# ID.4 Pure Performance                 e-tron S 55 quattro
# C40 Recharge                                 I-Pace EV400
# XC40 Recharge Pure Electric       Cybertruck Single Motor
# XC40 Recharge Twin Pure Electric             I-Pace EV400
#
#                                                                7th  \
# Model
# U5                                               e-tron 55 quattro
# e-tron 50 quattro                      e-tron Sportback 55 quattro
# e-tron 55 quattro                 XC40 Recharge Twin Pure Electric
# e-tron GT quattro                           EV6 Standard Range 2WD
# e-tron GT RS                                           iX xDrive50
# ...                                                            ...
# ID.4 Pure                         XC40 Recharge Twin Pure Electric
# ID.4 Pure Performance             XC40 Recharge Twin Pure Electric
# C40 Recharge                                 ID.4 Pure Performance
# XC40 Recharge Pure Electric                  Mustang Mach-E SR AWD
# XC40 Recharge Twin Pure Electric                 M-Byte 95 kWh 2WD
#
#                                                          8th  \
# Model
# U5                                             e-Soul 64 kWh
# e-tron 50 quattro                 IONIQ 5 Standard Range AWD
# e-tron 55 quattro                              e-Soul 64 kWh
# e-tron GT quattro                       Marvel R Performance
# e-tron GT RS                                     i4 eDrive40
# ...                                                      ...
# ID.4 Pure                                e-tron S 55 quattro
# ID.4 Pure Performance                                   Sion
# C40 Recharge                               M-Byte 95 kWh 2WD
# XC40 Recharge Pure Electric            ID.4 Pure Performance
# XC40 Recharge Twin Pure Electric           M-Byte 95 kWh 4WD
#
#                                                             9th  \
# Model
# U5                                         Q4 e-tron 50 quattro
# e-tron 50 quattro                 2 Standard Range Single Motor
# e-tron 55 quattro                                  C40 Recharge
# e-tron GT quattro                                  e-tron GT RS
# e-tron GT RS                        e-tron Sportback 55 quattro
# ...                                                         ...
# ID.4 Pure                         e-tron S Sportback 55 quattro
# ID.4 Pure Performance             e-tron S Sportback 55 quattro
# C40 Recharge                                          ID.4 Pure
# XC40 Recharge Pure Electric                           ID.4 Pure
# XC40 Recharge Twin Pure Electric          ID.4 Pure Performance
#
#                                                          10th
# Model
# U5                                          Crossback E-Tense
# e-tron 50 quattro                               e-Niro 39 kWh
# e-tron 55 quattro                               Zoe ZE50 R135
# e-tron GT quattro                                    Taycan 4
# e-tron GT RS                                   EQC 400 4MATIC
# ...                                                       ...
# ID.4 Pure                         XC40 Recharge Pure Electric
# ID.4 Pure Performance             XC40 Recharge Pure Electric
# C40 Recharge                                M-Byte 95 kWh 4WD
# XC40 Recharge Pure Electric                 M-Byte 95 kWh 4WD
# XC40 Recharge Twin Pure Electric                    ID.4 Pure
#
# [176 rows x 10 columns]

# %%
# similar.reset_index(inplace=True)
similar.rename_axis("index",  inplace=True)

# %%
similar
# Out:
# Model                             Model        U5  e-tron 50 quattro  \
# index
# 0                                    U5       NaN           0.999474
# 1                     e-tron 50 quattro  0.999474                NaN
# 2                     e-tron 55 quattro  0.999123           0.998042
# 3                     e-tron GT quattro  0.987849           0.987231
# 4                          e-tron GT RS  0.977518           0.976152
# ...                                 ...       ...                ...
# 171                           ID.4 Pure  0.995754           0.995484
# 172               ID.4 Pure Performance  0.995814           0.995566
# 173                        C40 Recharge  0.996394           0.995073
# 174         XC40 Recharge Pure Electric  0.995384           0.993974
# 175    XC40 Recharge Twin Pure Electric  0.996368           0.994973
#
# Model  e-tron 55 quattro  e-tron GT quattro  e-tron GT RS  \
# index
# 0               0.999123           0.987849      0.977518
# 1               0.998042           0.987231      0.976152
# 2                    NaN           0.992183      0.984856
# 3               0.992183                NaN      0.995940
# 4               0.984856           0.995940           NaN
# ...                  ...                ...           ...
# 171             0.997553           0.991731      0.988924
# 172             0.997665           0.991895      0.989086
# 173             0.998685           0.991720      0.988897
# 174             0.997484           0.988230      0.986474
# 175             0.998700           0.991783      0.988966
#
# Model  e-tron S 55 quattro  e-tron S Sportback 55 quattro  \
# index
# 0                 0.995893                       0.995026
# 1                 0.994610                       0.993617
# 2                 0.998123                       0.997733
# 3                 0.989991                       0.990790
# 4                 0.987754                       0.989354
# ...                    ...                            ...
# 171               0.998995                       0.998934
# 172               0.999106                       0.999047
# 173               0.999893                       0.999867
# 174               0.999873                       0.999770
# 175               0.999872                       0.999858
#
# Model  e-tron Sportback 50 quattro  e-tron Sportback 55 quattro  ...  \
# index                                                            ...
# 0                         0.999327                     0.983268  ...
# 1                         0.999558                     0.980653  ...
# 2                         0.999056                     0.989388  ...
# 3                         0.990394                     0.988479  ...
# 4                         0.981803                     0.994156  ...
# ...                            ...                          ...  ...
# 171                       0.997765                     0.993709  ...
# 172                       0.997845                     0.993804  ...
# 173                       0.997370                     0.995078  ...
# 174                       0.996361                     0.995210  ...
# 175                       0.997286                     0.995142  ...
#
# Model  ID.3 Pro S - 4 Seats  ID.3 Pro S - 5 Seats  ID.3 Pure Performance  \
# index
# 0                  0.980217              0.980226               0.996665
# 1                  0.980775              0.980782               0.997426
# 2                  0.973887              0.973884               0.997477
# 3                  0.959712              0.959686               0.994099
# 4                  0.932254              0.932225               0.987473
# ...                     ...                   ...                    ...
# 171                0.959713              0.959719               0.998418
# 172                0.959815              0.959822               0.998435
# 173                0.961084              0.961086               0.996723
# 174                0.956901              0.956907               0.995331
# 175                0.961120              0.961121               0.996617
#
# Model  ID.4 GTX  ID.4 Pro Performance  ID.4 Pure  ID.4 Pure Performance  \
# index
# 0      0.997377              0.994634   0.995754               0.995814
# 1      0.997147              0.994313   0.995484               0.995566
# 2      0.995665              0.991096   0.997553               0.997665
# 3      0.987365              0.978156   0.991731               0.991895
# 4      0.971973              0.958993   0.988924               0.989086
# ...         ...                   ...        ...                    ...
# 171    0.988712              0.981702        NaN               0.999984
# 172    0.988827              0.981781   0.999984                    NaN
# 173    0.989654              0.983110   0.999075               0.999182
# 174    0.986881              0.980422   0.998871               0.998923
# 175    0.989676              0.983143   0.998997               0.999102
#
# Model  C40 Recharge  XC40 Recharge Pure Electric  \
# index
# 0          0.996394                     0.995384
# 1          0.995073                     0.993974
# 2          0.998685                     0.997484
# 3          0.991720                     0.988230
# 4          0.988897                     0.986474
# ...             ...                          ...
# 171        0.999075                     0.998871
# 172        0.999182                     0.998923
# 173             NaN                     0.999619
# 174        0.999619                          NaN
# 175        0.999997                     0.999596
#
# Model  XC40 Recharge Twin Pure Electric
# index
# 0                              0.996368
# 1                              0.994973
# 2                              0.998700
# 3                              0.991783
# 4                              0.988966
# ...                                 ...
# 171                            0.998997
# 172                            0.999102
# 173                            0.999997
# 174                            0.999596
# 175                                 NaN
#
# [176 rows x 177 columns]

# %%
for x in result_top10.columns:
    result_top10[x+"_Val"] = similar.lookup(similar.index, result_top10[x])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-187-3e85f410e926> in <module>
#       1 for x in result_top10.columns:
# ----> 2     result_top10[x+"_Val"] = similar.lookup(similar.index, result_top10[x])
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in lookup(self, row_labels, col_labels)
#    3839         if not (self.index.is_unique and self.columns.is_unique):
#    3840             # GH#33041
# -> 3841             raise ValueError("DataFrame.lookup requires unique index and columns")
#    3842
#    3843         thresh = 1000
#
# ValueError: DataFrame.lookup requires unique index and columns

# %%
for x in result_top10.columns:
    print(x)
# Out:
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th
# 10th

# %%
similar = similar.set_index(df["index"]).drop(columns="index")

# %%
similar.lookup(similar.index, result_top10['1st'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-52b3de85ca8f> in <module>
# ----> 1 similar.lookup(similar.index, result_top10['1st'])
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in lookup(self, row_labels, col_labels)
#    3839         if not (self.index.is_unique and self.columns.is_unique):
#    3840             # GH#33041
# -> 3841             raise ValueError("DataFrame.lookup requires unique index and columns")
#    3842
#    3843         thresh = 1000
#
# ValueError: DataFrame.lookup requires unique index and columns

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-e0b6cd305aed> in <module>
# ----> 1 similar.lookup(1,1)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in lookup(self, row_labels, col_labels)
#    3834             The found values.
#    3835         """
# -> 3836         n = len(row_labels)
#    3837         if n != len(col_labels):
#    3838             raise ValueError("Row labels must have same size as column labels")
#
# TypeError: object of type 'int' has no len()

# %%
similar[similar < .999999]
# Out:
# Model                                   U5  e-tron 50 quattro  \
# Model
# U5                                     NaN           0.999474
# e-tron 50 quattro                 0.999474                NaN
# e-tron 55 quattro                 0.999123           0.998042
# e-tron GT quattro                 0.987849           0.987231
# e-tron GT RS                      0.977518           0.976152
# ...                                    ...                ...
# ID.4 Pure                         0.995754           0.995484
# ID.4 Pure Performance             0.995814           0.995566
# C40 Recharge                      0.996394           0.995073
# XC40 Recharge Pure Electric       0.995384           0.993974
# XC40 Recharge Twin Pure Electric  0.996368           0.994973
#
# Model                             e-tron 55 quattro  e-tron GT quattro  \
# Model
# U5                                         0.999123           0.987849
# e-tron 50 quattro                          0.998042           0.987231
# e-tron 55 quattro                               NaN           0.992183
# e-tron GT quattro                          0.992183                NaN
# e-tron GT RS                               0.984856           0.995940
# ...                                             ...                ...
# ID.4 Pure                                  0.997553           0.991731
# ID.4 Pure Performance                      0.997665           0.991895
# C40 Recharge                               0.998685           0.991720
# XC40 Recharge Pure Electric                0.997484           0.988230
# XC40 Recharge Twin Pure Electric           0.998700           0.991783
#
# Model                             e-tron GT RS  e-tron S 55 quattro  \
# Model
# U5                                    0.977518             0.995893
# e-tron 50 quattro                     0.976152             0.994610
# e-tron 55 quattro                     0.984856             0.998123
# e-tron GT quattro                     0.995940             0.989991
# e-tron GT RS                               NaN             0.987754
# ...                                        ...                  ...
# ID.4 Pure                             0.988924             0.998995
# ID.4 Pure Performance                 0.989086             0.999106
# C40 Recharge                          0.988897             0.999893
# XC40 Recharge Pure Electric           0.986474             0.999873
# XC40 Recharge Twin Pure Electric      0.988966             0.999872
#
# Model                             e-tron S Sportback 55 quattro  \
# Model
# U5                                                     0.995026
# e-tron 50 quattro                                      0.993617
# e-tron 55 quattro                                      0.997733
# e-tron GT quattro                                      0.990790
# e-tron GT RS                                           0.989354
# ...                                                         ...
# ID.4 Pure                                              0.998934
# ID.4 Pure Performance                                  0.999047
# C40 Recharge                                           0.999867
# XC40 Recharge Pure Electric                            0.999770
# XC40 Recharge Twin Pure Electric                       0.999858
#
# Model                             e-tron Sportback 50 quattro  \
# Model
# U5                                                   0.999327
# e-tron 50 quattro                                    0.999558
# e-tron 55 quattro                                    0.999056
# e-tron GT quattro                                    0.990394
# e-tron GT RS                                         0.981803
# ...                                                       ...
# ID.4 Pure                                            0.997765
# ID.4 Pure Performance                                0.997845
# C40 Recharge                                         0.997370
# XC40 Recharge Pure Electric                          0.996361
# XC40 Recharge Twin Pure Electric                     0.997286
#
# Model                             e-tron Sportback 55 quattro  \
# Model
# U5                                                   0.983268
# e-tron 50 quattro                                    0.980653
# e-tron 55 quattro                                    0.989388
# e-tron GT quattro                                    0.988479
# e-tron GT RS                                         0.994156
# ...                                                       ...
# ID.4 Pure                                            0.993709
# ID.4 Pure Performance                                0.993804
# C40 Recharge                                         0.995078
# XC40 Recharge Pure Electric                          0.995210
# XC40 Recharge Twin Pure Electric                     0.995142
#
# Model                             e-tron Sportback 55 quattro  ...  \
# Model                                                          ...
# U5                                                   0.999668  ...
# e-tron 50 quattro                                    0.998940  ...
# e-tron 55 quattro                                    0.999364  ...
# e-tron GT quattro                                    0.990446  ...
# e-tron GT RS                                         0.979927  ...
# ...                                                       ...  ...
# ID.4 Pure                                            0.995178  ...
# ID.4 Pure Performance                                0.995294  ...
# C40 Recharge                                         0.996267  ...
# XC40 Recharge Pure Electric                          0.994618  ...
# XC40 Recharge Twin Pure Electric                     0.996277  ...
#
# Model                             ID.3 Pro S - 4 Seats  ID.3 Pro S - 5 Seats  \
# Model
# U5                                            0.980217              0.980226
# e-tron 50 quattro                             0.980775              0.980782
# e-tron 55 quattro                             0.973887              0.973884
# e-tron GT quattro                             0.959712              0.959686
# e-tron GT RS                                  0.932254              0.932225
# ...                                                ...                   ...
# ID.4 Pure                                     0.959713              0.959719
# ID.4 Pure Performance                         0.959815              0.959822
# C40 Recharge                                  0.961084              0.961086
# XC40 Recharge Pure Electric                   0.956901              0.956907
# XC40 Recharge Twin Pure Electric              0.961120              0.961121
#
# Model                             ID.3 Pure Performance  ID.4 GTX  \
# Model
# U5                                             0.996665  0.997377
# e-tron 50 quattro                              0.997426  0.997147
# e-tron 55 quattro                              0.997477  0.995665
# e-tron GT quattro                              0.994099  0.987365
# e-tron GT RS                                   0.987473  0.971973
# ...                                                 ...       ...
# ID.4 Pure                                      0.998418  0.988712
# ID.4 Pure Performance                          0.998435  0.988827
# C40 Recharge                                   0.996723  0.989654
# XC40 Recharge Pure Electric                    0.995331  0.986881
# XC40 Recharge Twin Pure Electric               0.996617  0.989676
#
# Model                             ID.4 Pro Performance  ID.4 Pure  \
# Model
# U5                                            0.994634   0.995754
# e-tron 50 quattro                             0.994313   0.995484
# e-tron 55 quattro                             0.991096   0.997553
# e-tron GT quattro                             0.978156   0.991731
# e-tron GT RS                                  0.958993   0.988924
# ...                                                ...        ...
# ID.4 Pure                                     0.981702        NaN
# ID.4 Pure Performance                         0.981781   0.999984
# C40 Recharge                                  0.983110   0.999075
# XC40 Recharge Pure Electric                   0.980422   0.998871
# XC40 Recharge Twin Pure Electric              0.983143   0.998997
#
# Model                             ID.4 Pure Performance  C40 Recharge  \
# Model
# U5                                             0.995814      0.996394
# e-tron 50 quattro                              0.995566      0.995073
# e-tron 55 quattro                              0.997665      0.998685
# e-tron GT quattro                              0.991895      0.991720
# e-tron GT RS                                   0.989086      0.988897
# ...                                                 ...           ...
# ID.4 Pure                                      0.999984      0.999075
# ID.4 Pure Performance                               NaN      0.999182
# C40 Recharge                                   0.999182           NaN
# XC40 Recharge Pure Electric                    0.998923      0.999619
# XC40 Recharge Twin Pure Electric               0.999102      0.999997
#
# Model                             XC40 Recharge Pure Electric  \
# Model
# U5                                                   0.995384
# e-tron 50 quattro                                    0.993974
# e-tron 55 quattro                                    0.997484
# e-tron GT quattro                                    0.988230
# e-tron GT RS                                         0.986474
# ...                                                       ...
# ID.4 Pure                                            0.998871
# ID.4 Pure Performance                                0.998923
# C40 Recharge                                         0.999619
# XC40 Recharge Pure Electric                               NaN
# XC40 Recharge Twin Pure Electric                     0.999596
#
# Model                             XC40 Recharge Twin Pure Electric
# Model
# U5                                                        0.996368
# e-tron 50 quattro                                         0.994973
# e-tron 55 quattro                                         0.998700
# e-tron GT quattro                                         0.991783
# e-tron GT RS                                              0.988966
# ...                                                            ...
# ID.4 Pure                                                 0.998997
# ID.4 Pure Performance                                     0.999102
# C40 Recharge                                              0.999997
# XC40 Recharge Pure Electric                               0.999596
# XC40 Recharge Twin Pure Electric                               NaN
#
# [176 rows x 176 columns]

# %%
similar[similar < 1]
# Out:
# Model                                   U5  e-tron 50 quattro  \
# Model
# U5                                     NaN           0.999474
# e-tron 50 quattro                 0.999474                NaN
# e-tron 55 quattro                 0.999123           0.998042
# e-tron GT quattro                 0.987849           0.987231
# e-tron GT RS                      0.977518           0.976152
# ...                                    ...                ...
# ID.4 Pure                         0.995754           0.995484
# ID.4 Pure Performance             0.995814           0.995566
# C40 Recharge                      0.996394           0.995073
# XC40 Recharge Pure Electric       0.995384           0.993974
# XC40 Recharge Twin Pure Electric  0.996368           0.994973
#
# Model                             e-tron 55 quattro  e-tron GT quattro  \
# Model
# U5                                         0.999123           0.987849
# e-tron 50 quattro                          0.998042           0.987231
# e-tron 55 quattro                               NaN           0.992183
# e-tron GT quattro                          0.992183                NaN
# e-tron GT RS                               0.984856           0.995940
# ...                                             ...                ...
# ID.4 Pure                                  0.997553           0.991731
# ID.4 Pure Performance                      0.997665           0.991895
# C40 Recharge                               0.998685           0.991720
# XC40 Recharge Pure Electric                0.997484           0.988230
# XC40 Recharge Twin Pure Electric           0.998700           0.991783
#
# Model                             e-tron GT RS  e-tron S 55 quattro  \
# Model
# U5                                    0.977518             0.995893
# e-tron 50 quattro                     0.976152             0.994610
# e-tron 55 quattro                     0.984856             0.998123
# e-tron GT quattro                     0.995940             0.989991
# e-tron GT RS                               NaN             0.987754
# ...                                        ...                  ...
# ID.4 Pure                             0.988924             0.998995
# ID.4 Pure Performance                 0.989086             0.999106
# C40 Recharge                          0.988897             0.999893
# XC40 Recharge Pure Electric           0.986474             0.999873
# XC40 Recharge Twin Pure Electric      0.988966             0.999872
#
# Model                             e-tron S Sportback 55 quattro  \
# Model
# U5                                                     0.995026
# e-tron 50 quattro                                      0.993617
# e-tron 55 quattro                                      0.997733
# e-tron GT quattro                                      0.990790
# e-tron GT RS                                           0.989354
# ...                                                         ...
# ID.4 Pure                                              0.998934
# ID.4 Pure Performance                                  0.999047
# C40 Recharge                                           0.999867
# XC40 Recharge Pure Electric                            0.999770
# XC40 Recharge Twin Pure Electric                       0.999858
#
# Model                             e-tron Sportback 50 quattro  \
# Model
# U5                                                   0.999327
# e-tron 50 quattro                                    0.999558
# e-tron 55 quattro                                    0.999056
# e-tron GT quattro                                    0.990394
# e-tron GT RS                                         0.981803
# ...                                                       ...
# ID.4 Pure                                            0.997765
# ID.4 Pure Performance                                0.997845
# C40 Recharge                                         0.997370
# XC40 Recharge Pure Electric                          0.996361
# XC40 Recharge Twin Pure Electric                     0.997286
#
# Model                             e-tron Sportback 55 quattro  \
# Model
# U5                                                   0.983268
# e-tron 50 quattro                                    0.980653
# e-tron 55 quattro                                    0.989388
# e-tron GT quattro                                    0.988479
# e-tron GT RS                                         0.994156
# ...                                                       ...
# ID.4 Pure                                            0.993709
# ID.4 Pure Performance                                0.993804
# C40 Recharge                                         0.995078
# XC40 Recharge Pure Electric                          0.995210
# XC40 Recharge Twin Pure Electric                     0.995142
#
# Model                             e-tron Sportback 55 quattro  ...  \
# Model                                                          ...
# U5                                                   0.999668  ...
# e-tron 50 quattro                                    0.998940  ...
# e-tron 55 quattro                                    0.999364  ...
# e-tron GT quattro                                    0.990446  ...
# e-tron GT RS                                         0.979927  ...
# ...                                                       ...  ...
# ID.4 Pure                                            0.995178  ...
# ID.4 Pure Performance                                0.995294  ...
# C40 Recharge                                         0.996267  ...
# XC40 Recharge Pure Electric                          0.994618  ...
# XC40 Recharge Twin Pure Electric                     0.996277  ...
#
# Model                             ID.3 Pro S - 4 Seats  ID.3 Pro S - 5 Seats  \
# Model
# U5                                            0.980217              0.980226
# e-tron 50 quattro                             0.980775              0.980782
# e-tron 55 quattro                             0.973887              0.973884
# e-tron GT quattro                             0.959712              0.959686
# e-tron GT RS                                  0.932254              0.932225
# ...                                                ...                   ...
# ID.4 Pure                                     0.959713              0.959719
# ID.4 Pure Performance                         0.959815              0.959822
# C40 Recharge                                  0.961084              0.961086
# XC40 Recharge Pure Electric                   0.956901              0.956907
# XC40 Recharge Twin Pure Electric              0.961120              0.961121
#
# Model                             ID.3 Pure Performance  ID.4 GTX  \
# Model
# U5                                             0.996665  0.997377
# e-tron 50 quattro                              0.997426  0.997147
# e-tron 55 quattro                              0.997477  0.995665
# e-tron GT quattro                              0.994099  0.987365
# e-tron GT RS                                   0.987473  0.971973
# ...                                                 ...       ...
# ID.4 Pure                                      0.998418  0.988712
# ID.4 Pure Performance                          0.998435  0.988827
# C40 Recharge                                   0.996723  0.989654
# XC40 Recharge Pure Electric                    0.995331  0.986881
# XC40 Recharge Twin Pure Electric               0.996617  0.989676
#
# Model                             ID.4 Pro Performance  ID.4 Pure  \
# Model
# U5                                            0.994634   0.995754
# e-tron 50 quattro                             0.994313   0.995484
# e-tron 55 quattro                             0.991096   0.997553
# e-tron GT quattro                             0.978156   0.991731
# e-tron GT RS                                  0.958993   0.988924
# ...                                                ...        ...
# ID.4 Pure                                     0.981702        NaN
# ID.4 Pure Performance                         0.981781   0.999984
# C40 Recharge                                  0.983110   0.999075
# XC40 Recharge Pure Electric                   0.980422   0.998871
# XC40 Recharge Twin Pure Electric              0.983143   0.998997
#
# Model                             ID.4 Pure Performance  C40 Recharge  \
# Model
# U5                                             0.995814      0.996394
# e-tron 50 quattro                              0.995566      0.995073
# e-tron 55 quattro                              0.997665      0.998685
# e-tron GT quattro                              0.991895      0.991720
# e-tron GT RS                                   0.989086      0.988897
# ...                                                 ...           ...
# ID.4 Pure                                      0.999984      0.999075
# ID.4 Pure Performance                               NaN      0.999182
# C40 Recharge                                   0.999182           NaN
# XC40 Recharge Pure Electric                    0.998923      0.999619
# XC40 Recharge Twin Pure Electric               0.999102      0.999997
#
# Model                             XC40 Recharge Pure Electric  \
# Model
# U5                                                   0.995384
# e-tron 50 quattro                                    0.993974
# e-tron 55 quattro                                    0.997484
# e-tron GT quattro                                    0.988230
# e-tron GT RS                                         0.986474
# ...                                                       ...
# ID.4 Pure                                            0.998871
# ID.4 Pure Performance                                0.998923
# C40 Recharge                                         0.999619
# XC40 Recharge Pure Electric                               NaN
# XC40 Recharge Twin Pure Electric                     0.999596
#
# Model                             XC40 Recharge Twin Pure Electric
# Model
# U5                                                        0.996368
# e-tron 50 quattro                                         0.994973
# e-tron 55 quattro                                         0.998700
# e-tron GT quattro                                         0.991783
# e-tron GT RS                                              0.988966
# ...                                                            ...
# ID.4 Pure                                                 0.998997
# ID.4 Pure Performance                                     0.999102
# C40 Recharge                                              0.999997
# XC40 Recharge Pure Electric                               0.999596
# XC40 Recharge Twin Pure Electric                               NaN
#
# [176 rows x 176 columns]

# %%
h = similar[similar < 1].unstack().transpose().drop_duplicates()

# %%
h
# Out:
# Model                        Model
# U5                           U5                                       NaN
#                              e-tron 50 quattro                   0.999474
#                              e-tron 55 quattro                   0.999123
#                              e-tron GT quattro                   0.987849
#                              e-tron GT RS                        0.977518
#                                                                    ...
# ID.4 Pure Performance        XC40 Recharge Pure Electric         0.998923
#                              XC40 Recharge Twin Pure Electric    0.999102
# C40 Recharge                 XC40 Recharge Pure Electric         0.999619
#                              XC40 Recharge Twin Pure Electric    0.999997
# XC40 Recharge Pure Electric  XC40 Recharge Twin Pure Electric    0.999596
# Length: 14197, dtype: float64

# %%
h.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-8e3fc82cda65> in <module>
# ----> 1 h.to_frame()
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'to_frame'

# %%
df = similar[similar < 1].unstack().transpose()

# %%
df = df.to_frame()

# %%
df.index.set_names(["Model", "Comparison Model"], inplace=True)

# %%
df.loc["Taycan Turbo"]
# Out:
#                                          0
# Comparison Model
# U5                                0.990800
# e-tron 50 quattro                 0.991304
# e-tron 55 quattro                 0.992635
# e-tron GT quattro                 0.997684
# e-tron GT RS                      0.987777
# ...                                    ...
# ID.4 Pure                         0.989671
# ID.4 Pure Performance             0.989852
# C40 Recharge                      0.989091
# XC40 Recharge Pure Electric       0.985011
# XC40 Recharge Twin Pure Electric  0.989100
#
# [176 rows x 1 columns]

# %%
df
# Out:
#                                                                           0
# Model                            Comparison Model
# U5                               U5                                     NaN
#                                  e-tron 50 quattro                 0.999474
#                                  e-tron 55 quattro                 0.999123
#                                  e-tron GT quattro                 0.987849
#                                  e-tron GT RS                      0.977518
# ...                                                                     ...
# XC40 Recharge Twin Pure Electric ID.4 Pure                         0.998997
#                                  ID.4 Pure Performance             0.999102
#                                  C40 Recharge                      0.999997
#                                  XC40 Recharge Pure Electric       0.999596
#                                  XC40 Recharge Twin Pure Electric       NaN
#
# [30976 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30976 entries, ('U5', 'U5') to ('XC40 Recharge Twin Pure Electric', 'XC40 Recharge Twin Pure Electric')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       30786 non-null  float64
# dtypes: float64(1)
# memory usage: 375.8+ KB

# %%
.unstack().transpose()\
    .sort_values( ascending=False)\
    .drop_duplicates()

# %%
# https://towardsdatascience.com/recommender-system-in-python-part-2-content-based-system-693a0e4bb306
def get_similar_movies(movie_title, n_ratings_filter=100, n_recommendations=5):
    similar = matrix.corrwith(matrix[movie_title])
    corr_similar = pd.DataFrame(similar, columns=['correlation'])
    corr_similar.dropna(inplace=True)
    
    orig = data.copy()
    
    corr_with_movie = pd.merge(
        left=corr_similar, 
        right=orig, 
        on='title')[['title', 'correlation', 'numRatings']].drop_duplicates().reset_index(drop=True)
    
    result = corr_with_movie[corr_with_movie['numRatings'] > n_ratings_filter].sort_values(by='correlation', ascending=False)
    
    return result.head(n_recommendations)

# %%
# # formatted_table(comparison_table)
# display(get_comparison_table(ev_df,car_1,car_2))
# print("*** shaded values are etimates ***")

# %%
# get_comparison_table(ev_df,car_1,car_2)

# %%
# a = get_data_table(car_1,car_2)

# %%
# (a[car_1][1]-a[car_2][1])

# %%
# diff = []

# for i in range(0,11):
    
#     try:
#         b = (int(a[car_1][i])) - (int(a[car_2][i]))
#     except:
#         try:
#             b = round((float(a[car_1][i].replace("*",""))) - (float(a[car_2][i].replace("*",""))),2)
#         except:
#             b = "NA"
#     diff.append(b)

# %%
# diff

# %%
# (float(a[car_1][1])) - (float(a[car_2][1]))

# %%
# a[car_1]

# %%
# (float(a[car_1][1].replace("*",""))) - (float(a[car_2][1].replace("*","")))

# %%
# (int(a[car_1][2])) - (int(a[car_2][2]))
# (float(a[car_1][2].replace("*",""))) - (float(a[car_2][2].replace("*","")))
